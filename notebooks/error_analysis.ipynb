# %% [markdown]
# # EvalRAG Error Analysis
#
# Use this notebook to inspect retrieval failures, LLM-generated decision labels, weak concept coverage, and playbook gaps after running `scripts/run_eval.py`.
#
# The current pipeline uses an OpenAI-compatible LLM by default and falls back to local Ollama `qwen3:8b` when the hosted call fails.
